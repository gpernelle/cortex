# %%
from __future__ import division
from utils import *
from functions import *
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

today = datetime.date.today()
todayStr = '%04d%02d%02d' % (today.year, today.month, today.day)
# todayStr = '20151005'
DIRECTORY = os.path.expanduser("~/Dropbox/0000 - PhD/figures/"+todayStr+"/")
if not os.path.exists(DIRECTORY):
    os.makedirs(DIRECTORY)

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
matplotlib.rc('xtick', labelsize=16) 
matplotlib.rc('ytick', labelsize=16) 
matplotlib.rc('axes', labelsize = 20)
matplotlib.rc('axes', titlesize = 20)

# %%
column_names =['model','f','I','res', 'nothing']
path = os.path.expanduser("/Users/GP1514/Dropbox/ICL-2014/Code/C-Code/cortex/data/resonance.csv")
# path = '/Users/guillaume/Downloads/bursts_val-c40_.csv'
df = pd.read_csv(path, names= column_names  , sep=";")
df.tail()
# Out:
#       model          f   I        res  nothing
# 87  cc-tchu   15.84890  50  461.57000      NaN
# 88  cc-tchu    7.07946  50  631.48300      NaN
# 89  cc-tchu   14.12540  50  483.54000      NaN
# 90  cc-tchu  158.48900  50   19.55860      NaN
# 91  cc-tchu  177.82800  50    9.29874      NaN

# %%
dataframe = df[df['I']==50]

# %%
vals = dataframe[['f', 'res']].get_values()

# %%
plt.semilogx(vals[:,0],vals[:,1], '.')
