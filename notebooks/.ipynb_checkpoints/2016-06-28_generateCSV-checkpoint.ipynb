# %%
from __future__ import division
from IO import *
from cycler import cycler
import matplotlib as mpl
# %matplotlib inline
from numba import autojit

# %load_ext autoreload
# %autoreload 2

today = datetime.date.today()
todayStr = '%04d%02d%02d' % (today.year, today.month, today.day)
# todayStr = '20151005'
DIRECTORY = os.path.expanduser("~/Dropbox/0000 - PhD/figures/"+todayStr+"/")
if not os.path.exists(DIRECTORY):
    os.makedirs(DIRECTORY)
    
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5bdaa314-fdb8-4cae-8434-91cefc1fdf16">Loading BokehJS ...</span>
#     </div>

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# Instantiate classes
cortex = Cortex()
trn = TRN()
gr = GRAPH(cortex)

# styling
gammaColor = '#00cc99'

def xax(gamma, duration):
    x= np.arange(0,(duration-1)/1000,(duration)/1000/len(gamma) )
    return x

@autojit
def resonanceFS(F, tauv=15):
    T = 2000
    dt = 1
    t = np.arange(0, T, dt)
    F = np.logspace(0.5, 2.3, 200)

    res_var = np.empty(len(F), dtype=np.float64)
    b = 2
    for k, f in enumerate(F):
        A = 0.01
        I = A * np.cos(2 * np.pi * f * t / 1000)
        res_v = []
        res_u = []
        u = 0
        t_rest = 0

        # izh neuron model for cortical fast spiking neurons (that burst)
        v = -60
        for i in range(len(t)):
            v += dt / tauv * ((v + 60) * (v + 50) - 20 * u + 8 * I[i])
            u += dt * 0.044 * ((v + 55) - u)
            if v > 25:
                v = -40
                u += 50
            if i * dt > 1500:
                res_v.append(v / A)

        var = np.var(res_v)
        #         var = np.max(res_v)-np.min(res_v)
        res_var[k] = var
    return res_var

# %%
# #-------------------------------
# # PARAMS SEARCH
# #-------------------------------
c = cortex
c.N = 400
c.g = 10
c.d1 = 10
c.d2 = 30000
c.d3 = 10
c.initTime()
c.sigma = 60
c.WII = 1400 #2800
c.S = 100
c.model = "gp-izh-subnetworks"
c.glob = 0

# shared weights
c.sG = 10
c.sWII = 10

c.FACT = 1
c.r=0

c.ratio = 15
c.LTD  = 1e-0*4.7e-6 * c.FACT * c.N
c.LTP = c.ratio * c.LTD

c.tauv=15
c.dt =0.25
c.with_currents = True

# for S in np.arange(50,400,50):
#     Parallel(n_jobs=8)(delayed(cortex.runSimulation)(N,0, G, S, d1, d2, d3, before, after, sigma, \
# WII, LTP, LTD) for G in np.linspace(1,9,"8))

sWIIList = [0,10]
sGList = [0,1,5,10,15,20,25]
sGList = np.arange(0,30,2)
LTDList = [1e-9*4.7e-6 * c.FACT * c.N, 1e-0*4.7e-6 * c.FACT * c.N]
taulist = np.arange(11,95,2)

# cortex.runSimulation()

# c.readSimulation()
# gr.plotWeights(tauv = c.tauv)


for c.d2 in [60000]:
    for c.sWII in sWIIList:
        for c.sG in sGList:
            for c.LTD in LTDList:
                c.LTP = c.ratio * c.LTD
                Parallel(n_jobs=54)(delayed(c.runSimulation)(i=0, tauv=c.tauv) for c.tauv in taulist)

df = pd.DataFrame(columns = ['tauv', 'd2','sWII', 'sG', 'LTD',
                             'maxBegin', 'argmaxBegin', 'maxEnd', 'argmaxEnd',
                            'f1Begin', 'p1Begin', 'f2Begin', 'p2Begin', 
                             'f1End', 'p1End', 'f2End', 'p2End', 
                             'fBothStart', 'pBothStart', 'fBothEnd', 'pBothEnd', 'key'])
i=0
for c.tauv in taulist:
    for c.d2 in [60000]:
        for c.sWII in sWIIList:
            for c.sG in sGList:
                for c.LTD in LTDList:
                    c.LTP = c.ratio * c.LTD
                    print(c.tauv, c.sWII, c.sG)
                    c.with_currents=True
                    c.readSimulation()
                    csd = gr.valCSD()
                    if c.tauv <=35 and c.sG<=10:
                        key=-2
                    elif c.tauv>35 and c.sG<=10:
                        key=-1
                    elif c.tauv<=35 and c.sG>10:
                        key=2
                    elif c.tauv>35 and c.sG>10:
                        key=1
                    else:
                        key=0
                    df.loc[i] = [c.tauv, c.d2, c.sWII, c.sG, c.LTD>1e-8, 
                                 csd['maxBegin'], csd['argmaxBegin'], csd['maxEnd'], csd['argmaxEnd'],
                                csd['f1Begin'][0], csd['f1Begin'][1], csd['f2Begin'][0], csd['f2Begin'][1],
                                csd['f1End'][0], csd['f1End'][1], csd['f2End'][0], csd['f2End'][1],
                                 csd['fBothBegin'][0], csd['fBothBegin'][1], csd['fBothEnd'][0], csd['fBothEnd'][1],
                                key]
                    i+=1
print(i)
    
df.to_csv(DIRECTORY+'df-plast-ok2.csv')
# Out:
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 11
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 13
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 15
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 17
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 19
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 21
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 23
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 25
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 27
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 29
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 31
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 33
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 35
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 37
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 39
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 41
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 43
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 45
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 47
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 49
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 51
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 53
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 55
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 57
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 59
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 61
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 63
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 65
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 67
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 69
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 71
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 73
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 77
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 75
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 79
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 81
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 83
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 85
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 87
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 89
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 91
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 2.82e-11 -LTD 1.88e-12 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 93
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 11
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 19
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 13
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 15
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 17
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 23
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 25
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 27
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 21
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 29
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 31
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 33
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 35
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 37
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 39
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 41
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 43
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 45
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 47
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 49
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 51
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 53
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 57
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 55
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 59
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 61
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 63
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 65
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 67
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 69
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 73
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 71
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 75
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 79
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 77
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 81
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 83
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 85
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 89
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 87
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 93
# ./cortex -N 400 -ext _0.txt -d1 10 -d2 60000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0282 -LTD 0.00188 -model gp-izh-subnetworks -r 0 -global 0 -sG 0 -sWII 0 -tauv 91

# %% [markdown]
# -1   1
#
# -2   2

# %%
c.readSimulation()
# Out:
# can' find:	 /mnt/DATA/gp1514/Projects/github/cortex/data/gamma_g-10_TImean-30_T-60020_Glob-0_dt-0.25_N-200_r-0_S-100_WII-1400_LTD-9.4e-13_LTP-1.41e-11_model-gp-izh-subnetworks_sG-0_sWII-0_tauv-11_0.txt
# 0

# %%
# df.to_csv(DIRECTORY+'df-extended.csv')

# %%
# df = pd.read_csv('/Users/GP1514/Dropbox/0000 - PhD/figures/20160615/'+'df-extended8000plast-ok2.csv')
df = pd.read_csv(DIRECTORY + 'df-plast-ok.csv')

# %%
df['fBothBegin'] = df['fBothStart']
df['pBothBegin'] = df['pBothStart']

# %%
# df.to_csv(DIRECTORY+'df-extended8000plast-ok.csv')

# %%
dfplast = df[(df['LTD']==True)]
dfnoplast = df[(df['LTD']==False)]
dfplast.head()
dfnoplast.head()
# Out:
#    Unnamed: 0  tauv       d2  sWII    sG    LTD  maxBegin  argmaxBegin  \
# 0           0  11.0  60000.0   0.0   0.0  False       NaN          0.0
# 2           2  11.0  60000.0   0.0   4.0  False       NaN          0.0
# 4           4  11.0  60000.0   0.0   8.0  False       NaN          0.0
# 6           6  11.0  60000.0   0.0  12.0  False       NaN          0.0
# 8           8  11.0  60000.0   0.0  16.0  False       NaN          0.0
#
#    maxEnd  argmaxEnd     ...      p1End  f2End  p2End  fBothStart  pBothStart  \
# 0     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 2     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 4     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 6     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 8     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
#
#    fBothEnd  pBothEnd  key  fBothBegin  pBothBegin
# 0       0.0       NaN -2.0         0.0         NaN
# 2       0.0       NaN -2.0         0.0         NaN
# 4       0.0       NaN -2.0         0.0         NaN
# 6       0.0       NaN  2.0         0.0         NaN
# 8       0.0       NaN  2.0         0.0         NaN
#
# [5 rows x 25 columns]

# %%
c = cortex
c.with_currents = True
c.g = 10
c.d1 = 10
c.d2 = 60000
c.d3 = 10
c.T = 60020
c.tauv = 65
c.sG=0
c.sWII=0
# c.runSimulation(tauv=c.tauv)
gr.plotWeights(tauv=c.tauv)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-ebc4b47ebf67> in <module>()
#      10 c.sWII=0
#      11 # c.runSimulation(tauv=c.tauv)
# ---> 12 gr.plotWeights(tauv=c.tauv)
#
# /mnt/DATA/gp1514/Projects/github/cortex/notebooks/IO.py in plotWeights(self, tauv)
#     834
#     835         ax0 = fig.add_subplot(421)
# --> 836         ax0.plot(xax(c.gamma, c.T), c.gamma, color='g')
#     837         ax0.plot(xax(c.gammaN1, c.T), c.gammaN1*(1+0.0*c.sG), color='r')
#     838         ax0.plot(xax(c.gammaN2, c.T), c.gammaN2*(1+0.0*c.sG), color='c')
#
# /mnt/DATA/gp1514/Projects/github/cortex/notebooks/IO.py in xax(gamma, duration)
#       8
#       9 def xax(gamma, duration):
# ---> 10     x= np.arange(0,(duration-1)/1000,(duration)/1000/len(gamma) )
#      11     return x
#      12
#
# ZeroDivisionError: float division by zero

# %%
c = cortex
c.with_currents = True
c.g = 10
c.d1 = 10
c.d2 = 1000
c.d3 = 10
c.T = 1020
c.tauv = 65
c.sG=10
c.sWII=0
c.runSimulation(tauv=c.tauv)
# gr.plotWeights(tauv=c.tauv)
plt.plot(xax(c.gamma, c.T), c.gamma, color='g')
plt.plot(xax(c.gammaN1, c.T), c.gammaN1*(1+4*c.sG/c.N), color='r')
plt.plot(xax(c.gammaN2, c.T), c.gammaN2*(1+4*c.sG/c.N), color='c')

# for c.sG in sGList:
#     c.runSimulation(tauv=c.tauv)
#     c.readSimulation()
#     fig = plt.figure(figsize=(8,4))
#     ax0 = fig.add_subplot(111)
#     ax0.plot(xax(c.gamma, c.T), c.gamma, color='g')
#     ax0.plot(xax(c.gammaN1, c.T), c.gammaN1, color='r')
#     ax0.plot(xax(c.gammaN2, c.T), c.gammaN2, color='c')
#     plt.savefig(DIRECTORY+'gammaevol-sg%s.pdf'%str(c.sG))
# Out:
# ./cortex -N 200 -ext _0.txt -d1 10 -d2 1000 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 0.0141 -LTD 0.00094 -model gp-izh-subnetworks -r 0 -global 0 -sG 10 -sWII 0 -tauv 65
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-10-6c7f7e4a93a9> in <module>()
#      11 c.runSimulation(tauv=c.tauv)
#      12 # gr.plotWeights(tauv=c.tauv)
# ---> 13 plt.plot(xax(c.gamma, c.T), c.gamma, color='g')
#      14 plt.plot(xax(c.gammaN1, c.T), c.gammaN1*(1+4*c.sG/c.N), color='r')
#      15 plt.plot(xax(c.gammaN2, c.T), c.gammaN2*(1+4*c.sG/c.N), color='c')
#
# <ipython-input-3-7f79b1ecf039> in xax(gamma, duration)
#       8
#       9 def xax(gamma, duration):
# ---> 10     x= np.arange(0,(duration-1)/1000,(duration)/1000/len(gamma) )
#      11     return x
#      12
#
# ZeroDivisionError: float division by zero

# %%
fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
gr.plotCoherence(df,sG=0, ax=ax1)
gr.plotCoherence(df,sG=20, ax=ax2)
gr.plotArgCoherence(df,sG=0, ax=ax3)
gr.plotArgCoherence(df,sG=20, ax=ax4)
plt.savefig(DIRECTORY + 'cor.png')

# %%
fig = plt.figure(figsize=(12,12))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
gr.plotSGCoherence(df,tauv=15, ax=ax1)
gr.plotSGCoherence(df,tauv=35, ax=ax2)
gr.plotSGCoherence(df,tauv=55, ax=ax3)
gr.plotSGCoherence(df,tauv=85, ax=ax4)
plt.savefig(DIRECTORY + 'corSG.png')

# %%
c.tauv = 85
c.sG = 5
c.sWII = 10
c.readSimulation()
gr.plotWeights(c.tauv)
# Out:
# can't find:	 /mnt/DATA/gp1514/Projects/github/cortex/data/gamma_g-10_TImean-30_T-1020_Glob-0_dt-0.25_N-200_r-0_S-100_WII-1400_LTD-0.00094_LTP-0.0141_model-gp-izh-subnetworks_sG-5_sWII-10_tauv-85_0.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-7a505a5e31bd> in <module>()
#       2 c.sG = 5
#       3 c.sWII = 10
# ----> 4 c.readSimulation()
#       5 gr.plotWeights(c.tauv)
#
# /mnt/DATA/gp1514/Projects/github/cortex/notebooks/IO.py in readSimulation(self, i)
#     199
#     200         # try:
# --> 201         self.voltage = np.fromfile(v_p, dtype='double', count=-1, sep=" ")
#     202         self.adaptation = np.fromfile(u_p, dtype='double', count=-1, sep=" ")
#     203         # except:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/DATA/gp1514/Projects/github/cortex/data/v_g-10_TImean-30_T-1020_Glob-0_dt-0.25_N-200_r-0_S-100_WII-1400_LTD-0.00094_LTP-0.0141_model-gp-izh-subnetworks_sG-5_sWII-10_tauv-85_0.txt'

# %%
print(gr.fourier(c.i1[0:4000]))
print(gr.fourier(c.i2[0:4000]))
print(gr.fourier(c.i1[-4000:-1]))
print(gr.fourier(c.i2[-4000:-1]))
# Out:
# [41.95804195804196, 23.948810784322418]
# [29.970029970029969, 26.68449141823087]
# [41.95804195804196, 23.200402347951034]
# [29.970029970029969, 26.579698404884805]

# %%
c.LTD  = 1e-9*4.7e-6 * c.FACT * c.N
c.LTP = c.ratio * c.LTD
c.tauv=31
c.readSimulation()

plt.plot(c.i2[500:1500], color='c')
plt.plot(c.i1[500:1500])
plt.savefig(DIRECTORY+'i_start-sg10.pdf')
# Out:
# can't find:	 /mnt/DATA/gp1514/Projects/github/cortex/data/gamma_g-10_TImean-30_T-1020_Glob-0_dt-0.25_N-200_r-0_S-100_WII-1400_LTD-9.4e-13_LTP-1.41e-11_model-gp-izh-subnetworks_sG-5_sWII-10_tauv-31_0.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-6a89bb6d197d> in <module>()
#       2 c.LTP = c.ratio * c.LTD
#       3 c.tauv=31
# ----> 4 c.readSimulation()
#       5
#       6 plt.plot(c.i2[500:1500], color='c')
#
# /mnt/DATA/gp1514/Projects/github/cortex/notebooks/IO.py in readSimulation(self, i)
#     199
#     200         # try:
# --> 201         self.voltage = np.fromfile(v_p, dtype='double', count=-1, sep=" ")
#     202         self.adaptation = np.fromfile(u_p, dtype='double', count=-1, sep=" ")
#     203         # except:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/DATA/gp1514/Projects/github/cortex/data/v_g-10_TImean-30_T-1020_Glob-0_dt-0.25_N-200_r-0_S-100_WII-1400_LTD-9.4e-13_LTP-1.41e-11_model-gp-izh-subnetworks_sG-5_sWII-10_tauv-31_0.txt'

# %%
plt.plot(c.i2[-3000:-2000], color='c')
plt.plot(c.i1[-3000:-2000])
plt.savefig(DIRECTORY+'i_end-sg10.pdf')

# %%
dfnoplast.head()
# Out:
#    Unnamed: 0  tauv       d2  sWII    sG    LTD  maxBegin  argmaxBegin  \
# 0           0  11.0  60000.0   0.0   0.0  False       NaN          0.0
# 2           2  11.0  60000.0   0.0   4.0  False       NaN          0.0
# 4           4  11.0  60000.0   0.0   8.0  False       NaN          0.0
# 6           6  11.0  60000.0   0.0  12.0  False       NaN          0.0
# 8           8  11.0  60000.0   0.0  16.0  False       NaN          0.0
#
#    maxEnd  argmaxEnd     ...      p1End  f2End  p2End  fBothStart  pBothStart  \
# 0     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 2     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 4     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 6     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
# 8     NaN        0.0     ...        NaN    0.0    NaN         0.0         NaN
#
#    fBothEnd  pBothEnd  key  fBothBegin  pBothBegin
# 0       0.0       NaN -2.0         0.0         NaN
# 2       0.0       NaN -2.0         0.0         NaN
# 4       0.0       NaN -2.0         0.0         NaN
# 6       0.0       NaN  2.0         0.0         NaN
# 8       0.0       NaN  2.0         0.0         NaN
#
# [5 rows x 25 columns]

# %%
gr.plotEvolution(df, kind = 'frequency', LTD=True)
gr.plotEvolution(df, kind = 'frequency', LTD=False)
# Out:
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# 0

# %%
gr.plotEvolution(df, kind='power', LTD=True)
gr.plotEvolution(df, kind='power', LTD=False)
# Out:
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# 0

# %%
gr.plotCoherenceEvolution(df, kind='max', LTD=True)
gr.plotCoherenceEvolution(df, kind='max', LTD=False)
# Out:
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# 0

# %%
gr.plotCoherenceEvolution(df, kind='argmax', LTD=True)
gr.plotCoherenceEvolution(df, kind='argmax', LTD=False)
# Out:
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# 0

# %%
gr.plotCoherenceEvolution(df, kind='fBoth', LTD=True)
gr.plotCoherenceEvolution(df, kind='fBoth', LTD=False)

gr.plotCoherenceEvolution(df, kind='pBoth', LTD=True)
gr.plotCoherenceEvolution(df, kind='pBoth', LTD=False)
# Out:
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# (294,)
# (42, 7)
# 0

# %%
# def plotChange(dataframe, kind='max',network = '', both=None, vmin=None, vmax=None, sWII=10, title=""):
#     fig = plt.figure(figsize=(8,6))

    
#     df = dataframe
#     df = df[(df['LTD']==True)& (df['sWII']==sWII)]
#     extent = [np.min(df['sG']), np.max(df['sG']), np.min(df['tauv']), np.max(df['tauv'])]

#     ax1 = fig.add_subplot(111)

#     cmap = plt.cm.RdYlGn

#     title = r'%s'%(title)
#     column = kind + 'Begin'
#     filename = column + '.pdf'
#     ax1, im = gr.plotDiagramChangeCSD(fig, ax1, df, title, 
#                                       kind, filename, extent=extent, cmap = cmap, both=both,
#                                      vmin=vmin, vmax=vmax)

#     fig.subplots_adjust(right=0.95)
#     cbar_ax = fig.add_axes([0.85, 0.15, 0.02, 0.7])
#     cbar = fig.colorbar(im, cax=cbar_ax)

#     plt.savefig(DIRECTORY + kind + 'change_cluster.pdf')
    
# def plotChange2(dataframe, kind='max',network = '', title='', both=None, vmin=None, vmax=None, sWII=10):
#     fig = plt.figure(figsize=(8,12))
    
#     df = dataframe
#     df = df[(df['LTD']==True)& (df['sWII']==sWII)]
#     extent = [np.min(df['sG']), np.max(df['sG']), np.min(df['tauv']), np.max(df['tauv'])]

#     ax1 = fig.add_subplot(211)
#     ax2 = fig.add_subplot(212)
#     cmap = plt.cm.RdYlGn

#     title = r'%s'%(title)
#     column = kind + 'Begin'
#     filename = "".join(title.split(' ') )+ '.pdf'
#     ax1, im = gr.plotDiagramChangeCSD(fig, ax1, df, title, kind, filename, extent=extent, cmap = cmap,
#                                      both=both,
#                                      vmin=vmin, vmax=vmax)
    
#     title = r'%s'%(title)
#     column = kind[:-1] + '2Begin'
#     filename = "".join(title.split(' ') )+ '2.pdf'
#     ax2, im = gr.plotDiagramChangeCSD(fig, ax2, df, title, kind[:-1] + '2', filename, extent=extent, cmap = cmap,
#                                      both=both,
#                                      vmin=vmin, vmax=vmax)
    
#     ax2.set_title('')
#     ax1.set_xticks([])
#     ax1.set_xlabel("")
#     fig.subplots_adjust(right=0.95)
#     cbar_ax = fig.add_axes([0.85, 0.15, 0.02, 0.7])
#     cbar = fig.colorbar(im, cax=cbar_ax)
#     plt.tight_layout()
#     plt.savefig(DIRECTORY + kind + 'both_change_cluster.pdf')

# %%
gr.plotChange2(df, 'f', 'N1', both=True, title='Change of oscillation frequency', sWII=10, LTD=True)
gr.plotChange2(df, 'p', 'N1', both=True, title='Change of subnetwork coherence', sWII=10)
# plotChange('f1', 'N1')
# plotChange('f1', 'N1', both=True)
# plotChange('f2', 'N2', both=True)
# plotChange('p1', 'N1', both=True)
# plotChange('p2', 'N2', both=True)
gr.plotChange(df, 'max', title="Change of coherence between both networks")
gr.plotChange(df, 'argmax', vmin=0, vmax=40)
gr.plotChange(df, 'fBoth', title="Change of full internetwork frequency")
gr.plotChange(df, 'pBoth', title="Change of full internetwork coherence")
# Out:
# /mnt/DATA/gp1514/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/numpy/lib/function_base.py:3403: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# /mnt/DATA/gp1514/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ## Plot difference between with and without plasticity

# %%
gr.plotChangePlast2(df, 'f', 'N1', both=True, title='Change of oscillation frequency', sWII=10)
gr.plotChangePlast2(df, 'p', 'N1', both=True, title='Change of subnetwork coherence', sWII=10)
# Out:
# /mnt/DATA/gp1514/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/numpy/lib/function_base.py:3403: RuntimeWarning: Invalid value encountered in median
#   RuntimeWarning)
# /mnt/DATA/gp1514/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
gr.plotChangePlast(df, 'max', title='Change of oscillation frequency', sWII=10)
gr.plotChangePlast(df, 'argmax', title='Change of subnetwork coherence', sWII=10)
gr.plotChangePlast(df, 'fBoth', title='Change of oscillation frequency', sWII=10)
gr.plotChangePlast(df, 'pBoth', title='Change of subnetwork coherence', sWII=10)

# %%
# c = cortex
c.with_currents = True
c.N = 300
c.g = 10
c.d1 = 10
c.d2 = 1012
c.d3 = 10
c.T = 1020
c.tauv = 15
c.sG=20
c.sWII=0
c.dt=0.25
# c.runSimulation(tauv=c.tauv)
# c.readSimulation()
# gr.plotWeights(tauv=c.tauv)

# %%
t0 = t.time()

c.runSimulation(tauv=c.tauv)
print(t.time()-t0)
# Out:
# ./cortex -N 300 -ext _0.txt -d1 10 -d2 1012 -d3 10 -before 10 -after 30010 -S 100 -G 10 -s 60 -WII 1400 -LTP 1.41e-11 -LTD 9.4e-13 -model gp-izh-subnetworks -r 0 -global 0 -sG 20 -sWII 0 -tauv 15
# 5.815515995025635

# %%
c.readSimulation()
plt.plot(c.voltage)
