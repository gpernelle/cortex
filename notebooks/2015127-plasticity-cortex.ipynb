# %%
from __future__ import division
from utils import *
from functions import *
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

today = datetime.date.today()
todayStr = '%04d%02d%02d' % (today.year, today.month, today.day)
# todayStr = '20151005'
DIRECTORY = os.path.expanduser("~/Dropbox/0000 - PhD/figures/"+todayStr+"/")
if not os.path.exists(DIRECTORY):
    os.makedirs(DIRECTORY)

# %%
from bokeh.io import output_notebook
output_notebook()
# Out:
#
# <script type="text/javascript">
#     /* BEGIN /Users/GP1514/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/bokeh/server/static/js/bokeh.min.js */
# ...

# %%
# Instantiate classes
cortex = Cortex()
trn = TRN()

# %%
#-------------------------------
# PARAMS SEARCH
#-------------------------------
N = 500
G = 8.1
d1 = 10
d2 = 80000
d3 = 10
before = d1
after = d2+d3
S = 150
sigma = 60
WII = 1400
LTP = 0.1
LTD = 7

data = Parallel(n_jobs=8)(delayed(cortex.readSimulation)(N, 0, G, S, d1, d2, d3, before, after, WII, LTP, LTD) for LTP in np.linspace(0,0.5,56))
# Out:
# can' find:	 /Users/GP1514/Dropbox/ICL-2014/Code/C-Code/cortex/data/gamma_g-8.1_TImean-50_T-80020_Glob-1_dt-0.25_N-500_S-150_WII-1400_LTD-7_LTP-0_0.txt

# %%
S=150
# data = Parallel(n_jobs=8)(delayed(cortex.readSimulation)(N, 0, G, S, d1, d2, d3, before, after, WII, LTP, LTD) for LTP in np.linspace(0,0.5,56))
fig = plt.figure()
ax1 = fig.add_subplot(111)
colormap = plt.cm.gist_ncar
plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, len(data))])
for d in data:
    try:
        plt.plot(d[4])
    except:
        pass
    
plt.title('Gamma S - %d' %S)
plt.xlabel('Time [80s]')
plt.savefig(DIRECTORY + 'fixedpoint-S%d.pdf'%S)
# Out:
# /Users/GP1514/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
S=70
data = Parallel(n_jobs=8)(delayed(cortex.readSimulation)(N, 0, G, S, d1, d2, d3, before, after, WII, LTP, LTD) for LTP in np.linspace(0,0.5,56))
fig = plt.figure()
ax1 = fig.add_subplot(111)
colormap = plt.cm.gist_ncar
plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, len(data))])
for d in data:
    try:
        plt.plot(d[4])
    except:
        pass
    
plt.title('Gamma S - %d' %S)
plt.xlabel('Time [80s]')
plt.savefig(DIRECTORY + 'fixedpoint-S%d.pdf'%S)
# Out:
# can' find:	 /Users/GP1514/Dropbox/ICL-2014/Code/C-Code/cortex/data/gamma_g-8.1_TImean-50_T-80020_Glob-1_dt-0.25_N-500_S-70_WII-1400_LTD-7_LTP-0_0.txt
# /Users/GP1514/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#-------------------------------
# PARAMS SEARCH
#-------------------------------
N = 500
G = 8.1
d1 = 10
d2 = 80000
d3 = 10
before = d1
after = d2+d3
S = 70
sigma = 60
WII = 1400
LTP = 0.1
LTD = 7

Parallel(n_jobs=8)(delayed(cortex.runSimulation)(N,0, G, S, d1, d2, d3, before, after, sigma, WII, LTP, LTD) for LTP in np.linspace(0,0.5,56))
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
